# %%
#
import pandas as pd # per caricare dataset
import os # per cambiare directori se ci serve
# %matplotlib inline

# %%
os.getcwd()# prima cosa da fare controllare directory di dove siamo
# Out:
# '/Users/mirko/Desktop/Python/VisualizzazioniAvanzate'

# %%
movies = pd.read_csv('/Users/mirko/Desktop/Python/VisualizzazioniAvanzate/Movie-Ratings.csv') #mettiamo dataset nellla cartella dove stiamo lavorando 
                                                                                # e richiamiamolo

# %%
len(movies) # verificare sempre lunghezza per vedre se importa tutto
# Out:
# 559

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10.000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns # verificare che ci siano i titoli delle colonne
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
# rename columns
movies.columns = ['Film', 'Genre','CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10.000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# esploriamo il dataset 
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.describe() # ci da statistiche sui nomi # per l'anno il promedio non ha senso, vogliamo 
                                                # considerare l'ANNO sono rappresentati come VALORE num ma dobbiamo
                                                #trasformarlo in VARIABILE CATEGORICA
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.Film = movies.Film.astype('category') #trasformare in VARIABILE CATEGORICA

# %%
movies.head() # visualmente nulla cambia
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10.000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info() # ma in realtà anno è diventato una categoria
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
# fare qualcosa di simile con le altre colonne
movies.Genre = movies.Genre.astype('category') #trasformare in VARIABILE CATEGORICA
movies.Year = movies.Year.astype('category') #trasformare in VARIABILE CATEGORICA

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe() # ora non includerà nelle statistiche le colonne category type
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
#VISUALIZZAZIONE
from matplotlib import pyplot as plt
import seaborn as sns

# %%
####     JOINTPLOTS        #####

# %%
j = sns.jointplot(data=movies, x='CriticRating', y = 'AudienceRating') #grafico a dispersione che ci 
#mostra se ci sono correlazioni e se tracciamo una diagonale nel grafico il rating è maggiore della critica + alto 
#dati in alto e a destra per mostrare la distribuzione di ogni colonna

# %%
j = sns.jointplot(data=movies, x='CriticRating', y = 'AudienceRating', kind='hex') 
#per scoprire i parametri shift+tab, in hex si vedono i cluster molto meglio 
#associati alla distribuzione in alto (il diagramma sopra) e sx (diagramma a sx)

# %%
######## ISTOGRAMMI come crearli ripasso
# modo seaborn che aggiunge degli stili
sns.set_style('darkgrid', )
ml = sns.displot(movies.AudienceRating, bins=15)
#la valutazione del pubblico sembra distribuita normalmente a seconda dei sentimenti delle persone,

# %%
# modo con pyplot 
n1 = plt.hist(movies.CriticRating, bins=15) # la critica a diff del pubblico si comporta im modo diverso
# perchè ha dei criteri: luce suono ecc e la distrib normale si perde

# %%
########### GRAFICI A BARRE IMPILATE
#h = plt.hist(movies.BudgetMillions)
movies[movies.Genre == 'Drama'] # filtro per genere
# Out:
#                     Film  Genre  CriticRating  AudienceRating  BudgetMillions  \
# 10            88 Minutes  Drama             5              51              30
# 11    A Dangerous Method  Drama            79              89              20
# 13        A Serious Man   Drama            89              64               7
# 18          Albert Nobbs  Drama            53              43               8
# 23       All Good Things  Drama            33              64              20
# ..                   ...    ...           ...             ...             ...
# 529            War Horse  Drama            77              73              66
# 532  Water For Elephants  Drama            60              72              38
# 534     We Own the Night  Drama            55              63              21
# 541             Whip It   Drama            84              73              15
# 545        Winter's Bone  Drama            94              73               2
#
#      Year
# 10   2007
# ...

# %%
# prendiamo la colonna dal sottoinseme del dataframe

# %%
h = plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins=15) # Budget solo per genere dramma, bins uguale per tutti per migliorare leggermente la visualizzazione
h = plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=15) # Budget solo per thriller impilandosi ma un dietro l'altra
h = plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins=15) # Budget solo per thriller impilandosi ma un dietro l'altra

# %%
# passiamo una lista di colonne
# mettiamo in una lista 2 liste in un istrogramma
h1 = plt.hist([movies[movies.Genre == 'Action'].BudgetMillions, movies[movies.Genre == 'Drama'].BudgetMillions],\
             stacked=True, bins=15) # stacked impila le colonne ma dato che abbiamo moltissimi generi 
                                    # dobbiamo farlo in ciclo

# %%
# iterare i generi
for gen in movies.Genre.cat.categories: # prenere una lista tramite le variabili category dichiarete all'inizio
    print(gen) #verifica i valori presenti
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
list1 = [] # oppure list()
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    
h1 = plt.hist( list1,\
             stacked=True, bins=15, rwidth=1)

# %%
# etichette, aggiungere la legenda
list1 = [] # oppure list()
myLabels = list()

for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    myLabels.append(gen)
    
h2 = plt.hist( list1,\
             stacked=True, bins=15, rwidth=1, label=myLabels) # aggiungi la legenda
plt.legend() #   mostrare la legenda
plt.show()

# %%
############.  KDE PLOT 
# valutazione pubblico vs critica
vis = sns.lmplot(data=movies, x ='CriticRating', y='AudienceRating', fit_reg=False, hue='Genre', size=5,aspect=1) 
# almeno di non oler aver un'idea generale non è chiaro troppo complicato
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/regression.py:581: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# visualizzare nella galleria se abbiamo un grafico che serve al nostro scopo e utilizzarlo
k = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, cmap='Reds') ## si notano i punti + 
                            #densità e come è  distribuita man mano che ci allontaniamo dal centro 
                            #la densita di dati diminuisce
                            # è un modo per vedere come vengono distribuiti i nostri dati
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap='Reds')

# %%
# unendoli si ha il meglio delle due versioni
k = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, cmap='Reds') # se non si vede la griglia nei parametri aggiungere shade_lowest=False
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap='Reds')
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#############.  SUBPLOTS (sottografico, combinare grafici in + posizioni)
import seaborn as sns
sns.set_style ='dark'
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)# CImostra se baget film ha effeto sulla valutaz del pubblico
                                                                # effettivamente cambia
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating) # simili a sopra ma + largo
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f, ax = plt.subplots(1,2, figsize=(12,6)) # 1 riga e 2 colonne # 12 lunghezza 6 altezza # convenzione python

# %%
# uniamo i grafici

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))  # sunbplots ritorna una tupla che ha 2 oggetti fig e axes 
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
axes # prima parte 1 graf seconda parte 2 graf
# Out:
# array([<AxesSubplot:xlabel='BudgetMillions', ylabel='CriticRating'>,
#        <AxesSubplot:xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %%
# se abbiamo + righe è bidimensionale
f, axes = plt.subplots(2,2, figsize=(12,6)) 
k2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1])
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# moigliorare view
f, axes = plt.subplots(1,2, figsize=(12,6), sharex=True,sharey=True) # con share asse x share y non dobbiamo settare 
                                                                    # anche per k3
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axes[0])
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[1])
k2.set(xlim=(-20,160))  # arriverà fino a 160
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# [(-20.0, 160.0)]

# %%
############# ViolnPlots & Boxplots
w = sns.violinplot(data=movies, x='Genre', y='CriticRating')  # la largezza delle indica dove sono concentrate le 
                                                                # osservazioni

# %%
c = sns.boxplot(data=movies, x='Genre', y='CriticRating') #valori anomali vengono esclusi, mediana horromovies è la + alta
                                                        # in thriller media + alta
         # se stiamo creando u film se non abbiamo un idea quale sarebbe il migliore in cui investire ??
        # meglio investire in un thriller + possibilità critica buona
        # osserva in quartili il quartile + è alto colorato l'osservazione è maggiore

# %%
### violet plot da + info del box plots
z = c = sns.boxplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating') # sottoinsieme di film solo dramma
# possiamo vedere valutazione critica anno per anno
# osservazioni : Quello del 2011 è + lungo ma se compari nel violetplot sot è + morbido
# + usati dai dirigenti

# %%
c = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating') # qui i punti di concentrazione
    # ce le mostra quando abbiamo un valore sopra o sotto di mediana 
    # a differenza del box che non possiamo vederli
    # non sono molto usati solo perchè i per i dirigenti è + facile

# %%
###########
####### creating FACEGRID   griglie di sfaccettatura 
g = sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre') #prima il dataset 
                # prendiamo una visualizzazione di un dataset e lo dividiamo in fette per poi essere popolato 
                # a seconda dei parametri
        # da sx. adx abbiamo gli anni

# %%
# METODO MAP NEI GRAFICI passiamo un grafico ad espressione per ogni cella per genere e anno
# come mappare il grafico 
#plt.scatter(movies.CriticRating, movies.AudienceRating)

g = sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre') 
#g = g.map(plt.scatter,movies.CriticRating, movies.AudienceRating) #passiamo i parametri come se fossero x e y, che servono a plt.scatter
g = g.map(plt.scatter,'CriticRating', 'AudienceRating')

# %%
# POPOLARE IL FACEGRID. 
# ES MAPPIAMO GLI ISTOGRAMMI A CUI BASTA UNO DEI PARAMETRO PER PLOTTARE
g = sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre') 
g = g.map(plt.hist,'BudgetMillions') # VEDIAMO COME CAMBIA IL BUDGET PER OGNI GENERE

# %%
### back to scaret drop: quali altri argomenti come keywords possiamo passare ? 
g = sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre') 
kws = dict(s=50,linewidth = 0.5, edgecolor = 'black')   # passiamo un dizionario
g = g.map(plt.scatter,'CriticRating', 'AudienceRating', **kws) # **kws 
                                        #decomporre il dizonario e passarlo al grafico in python
    
    ### ogni riga è un genere si può vedere un trend attraverso gli anni con questo rapporto

# %%
######### coordinate e diagonali
#sopra la diagonale vuol die che il pubblico da + valutazione della critica e viceversa
#controllare assi e aggiungere diagonali
g = sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre') 
kws = dict(s=50,linewidth = 0.5, edgecolor = 'black')  
g = g.map(plt.scatter,'CriticRating', 'AudienceRating', **kws) 
g.set(xlim = (0,100), ylim = (0,100))# impostare i limiti per i assi x e y
for ax in g.axes.flat: # python non è vettorizzato e dobbiamo usare spesso i cicli 
    ax.plot((0,100),(0,100), c='gray', ls='--' )
                        # axes è un array che rappresenta ogni riquadro dei grafici, flat iteratore nell'array
        #si nota che il pubb ha dato voti migliori della critica

# %%
#aggiungiamo una legenda

g = sns.FacetGrid(movies,row='Genre',col='Year', hue='Genre') 
kws = dict(s=50,linewidth = 0.5, edgecolor = 'black')  
g = g.map(plt.scatter,'CriticRating', 'AudienceRating', **kws) 
g.set(xlim = (0,100), ylim = (0,100))
for ax in g.axes.flat: 
    ax.plot((0,100),(0,100), c='gray', ls='--')
g.add_legend()

# %%
####### Creare una DASHBOARD
# combina + set di informazioni
# con la funz subplots creiamo la dashboard. e la popoliamo
sns.set_style='dark'
f, axes = plt.subplots(2,2, figsize=(15,15))
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axes[0,0]) # dobbiamo passare posizione di ogni cella perchè è aforma di matrice la dashboard
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axes[0,1])
k2.set(xlim=(-20,160)) 
sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating',ax=axes[1,0]) # specificare dove mostrare il grafico
k = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, cmap='Reds', ax=axes[0,0]) # se non si vede la griglia nei parametri aggiungere shade_lowest=False
kb = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, cmap='Reds', ax=axes[1,1])
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap='Reds', ax=axes[1,1])
#possiamo aggiungere anche grafici non del pacchetto seaborn sns, ma impostiamo axes in modo differente 
# axes è un oggetto creato da pyplot, seaborn è un'altra libreria basata su pyplot
axes[1,1].hist(movies.CriticRating, bins=15)
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# ...

# %%
########### STILIZZARE I GRAFICI
#sns.set_style("darkgrid", {"axes.facecolor": "black"})# sovrascrivere stile predefinito
f, axes = plt.subplots(2,2, figsize=(15,15))
# plot 0,0
k = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, shade_lowest=True, cmap='inferno',\
                ax=axes[0,0])   # cmap color legato al palette dell'azienda mandataria, oppure qualcosa che attiri attenzione
kborder = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True, cmap='cool', shade_lowest=True,\
                ax=axes[0,0]) 
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, shade=True, shade_lowest=True, cmap='inferno',\
                 ax=axes[0,0])
k2border = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, shade=True, shade_lowest=True, cmap='cool',\
                 ax=axes[0,0])
k2.set(xlim=(-20,160)) 
# plot 0,1
k3 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, shade=True, shade_lowest=True, cmap='inferno',\
                 ax=axes[0,1])
k3border = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, shade=True, shade_lowest=True, cmap='cool',\
                 ax=axes[0,1])
# plot 1,0
sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='CriticRating', palette='YlOrRd',ax=axes[1,0]) 
# plot 1,1
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap='Reds', ax=axes[1,1])
axes[1,1].hist(movies.CriticRating, bins=15)
# Out:
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1718: UserWarning: `shade_lowest` is now deprecated in favor of `thresh`. Setting `thresh=0`, but please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/mirko/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
## cambiare font assi e molto altro
list1 = [] 
myLabels = list()

for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre == gen].BudgetMillions)
    myLabels.append(gen)  

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27) # size A4 paper
h4= plt.hist( list1,\
              stacked=True, bins=15, rwidth=1, label=myLabels)
plt.ylabel('Number of Movies', color='Red', fontsize=40)
plt.xlabel('Number of Movies', color='Green',fontsize=40)
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.title('Movie Budget Distribution', fontsize=35)# mettere titolo
plt.legend(frameon=True, fancybox=True, shadow=True, framealpha=0.5, prop={'size':20}) #passare parametri che richiama una dizionario per mofdificare legenda
plt.show()
