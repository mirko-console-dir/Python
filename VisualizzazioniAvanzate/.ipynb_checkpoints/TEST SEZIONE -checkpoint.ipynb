# %%
# Programmazione Python A-Z ™ © Kirill Eremenko
# INCASSO LORDO DOMESTICO DEI FILM
# Compito
# Il sito web di recensioni di film è rimasto molto
# soddisfatto del risultato del compito precedente e
# ora ha una nuova richiesta per te.
# Il consulente precedente aveva creato un grafico per
# loro, il quale verrà mostrato nella prossima slide.
# Tuttavia, il codice Python utilizzato per creare il
# diagramma è stato perso e non può essere
# recuperato. Il tuo compito è di scrivere il
# codice che ricrea lo stesso grafico facendolo
# sembrare il più vicino possibile
# all'originale
# È stato fornito un nuovo dataset.

# 1 Importiamo i packages necessari
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
# Import the data
mov = pd.read_csv('/Users/mirko/Desktop/Python/VisualizzazioniAvanzate/P4-Section6-Homework-Dataset.csv', encoding = 'latin1')

# %%
# Explore the dataset
mov.head()
# Out:
#                                       ï»¿Day of Week         Director   Genre  \
# 0                                             Friday        Brad Bird  action
# 1                                             Friday      Scott Waugh  action
# 2                                             Friday   Patrick Hughes  action
# 3  Friday,"Phil Lord, Chris Miller",comedy,21 Jum...              NaN     NaN
# 4                                             Friday  Roland Emmerich  action
#
#          Movie Title Release Date               Studio  \
# 0       Tomorrowland   22/05/2015  Buena Vista Studios
# 1     Need for Speed   14/03/2014  Buena Vista Studios
# 2  The Expendables 3   15/08/2014            Lionsgate
# 3                NaN          NaN                  NaN
# 4   White House Down   28/06/2013                 Sony
#
#    Adjusted Gross ($mill)  Budget ($mill)  Gross ($mill)  IMDb Rating  \
# 0                   202.1           170.0          202.1          6.7
# ...

# %%
# Check the summary of the dataframe
mov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 608 entries, 0 to 607
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ï»¿Day of Week          608 non-null    object
#  1   Director                483 non-null    object
#  2   Genre                   483 non-null    object
#  3   Movie Title             483 non-null    object
#  4   Release Date            483 non-null    object
#  5   Studio                  483 non-null    object
#  6   Adjusted Gross ($mill)  483 non-null    float64
#  7   Budget ($mill)          483 non-null    float64
#  8   Gross ($mill)           483 non-null    float64
#  9   IMDb Rating             483 non-null    float64
#  10  MovieLens Rating        483 non-null    float64
#  11  Overseas ($mill)        483 non-null    float64
#  12  Overseas%               483 non-null    float64
#  13  Profit ($mill)          483 non-null    float64
# ...

# %%
# Check the structure of the dataframe
mov.describe()
# Out:
#        Adjusted Gross ($mill)  Budget ($mill)  Gross ($mill)  IMDb Rating  \
# count              483.000000      483.000000     483.000000   483.000000
# mean               444.926087       88.971429     355.636439     6.832919
# std                182.915715       55.091103     153.541493     0.916274
# min                202.100000        3.500000     200.300000     3.600000
# 25%                297.600000       45.000000     239.650000     6.300000
# 50%                391.600000       80.000000     306.900000     6.800000
# 75%                556.300000      125.000000     414.500000     7.500000
# max                986.700000      263.700000     960.400000     8.900000
#
#        MovieLens Rating  Overseas ($mill)   Overseas%  Profit ($mill)  \
# count        483.000000        483.000000  483.000000      483.000000
# mean           3.301325        208.453209   57.554451      266.598758
# std            0.450423        110.142044   12.572576      135.917827
# ...

# %%
# Explore the categorical variable Studio, used in the assignment
mov.Studio.unique()
# Out:
# array(['Buena Vista Studios', 'Lionsgate', nan, 'Sony', 'Universal', 'WB',
#        'Weinstein Company', 'UA Entertainment', 'WB/New Line',
#        'Paramount Pictures', 'New Line Cinema', 'Fox', 'TriStar',
#        'Relativity Media', 'Screen Gems', 'StudioCanal',
#        'Fox Searchlight Pictures', 'MiraMax', 'Path_ Distribution',
#        'DreamWorks', 'Lionsgate Films', 'Revolution Studios',
#        'Dimension Films', 'USA', 'Lionsgate/Summit',
#        'Pacific Data/DreamWorks', 'Disney', 'Colombia Pictures',
#        'Gramercy Pictures', 'Summit Entertainment', 'Vestron Pictures',
#        'MGM', 'Orion', 'IFC', 'New Market Films'], dtype=object)

# %%
# Filter the dataframe by genre
#mov2 = mov[(mov.Studio == 'action') | (mov. == 'adventure') | (mov._ == 'animation') | (mov._ == 'comedy') | (mov._ == 'drama')]
genre_filters= ['action','adventure','animation','comedy','drama']
mov2 = mov[mov.Genre.isin(genre_filters)]
# Out:
# array(['action', 'adventure', 'animation', 'comedy', 'drama'],
#       dtype=object)

# %%
# Filter the dataframe by studio
#mov3 = mov2[(mov2._ == 'Buena Vista Studios') | (mov2._ == 'Fox') | (mov2._ == 'Paramount Pictures') | (mov2._ == 'Sony') | (mov2._ == 'Universal') | (mov2._ == 'WB')]
studio_filters = ['Buena Vista Studios','Fox','Paramount Pictures', 'Sony','Universal','WB']
mov3 = mov2[mov.Studio.isin(studio_filters)]
# Out:
# array(['Buena Vista Studios', 'Sony', 'Universal', 'WB',
#        'Paramount Pictures', 'Fox'], dtype=object)

# %%
# Check how the filters worked
print (mov2.Genre.unique())
print (mov3.Studio.unique())
print (len(mov3))
# Out:
# ['action' 'adventure' 'animation' 'comedy' 'drama']
# ['Buena Vista Studios' 'Sony' 'Universal' 'WB' 'Paramount Pictures' 'Fox']
# 336

# %%
# Define the style
sns.set(style="darkgrid", palette="muted", color_codes=True)

# Plot the boxsplots
ax = sns.boxplot(data=mov3, x='Genre', y='Gross % US', orient='v', color='lightgray', showfliers=False)
plt.setp(ax.artists, alpha=0.5)#definire trasparenze

# Add in points to show each observation
sns.stripplot(x='Genre', y='Gross % US', data=mov3, jitter=True, size=6, linewidth=0, hue = 'Studio', alpha=0.7)# aggiungiamo l'altro grafixo

ax.axes.set_title('Domestic Gross % by Genre',fontsize=30)
ax.set_xlabel('Genre',fontsize=20)
ax.set_ylabel('Gross % US',fontsize=20)

# Define where to place the legend
ax.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
